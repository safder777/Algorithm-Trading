# %% [markdown]
# ## Getting stock price & understand them

# %%
# import pandas_datareader.data as reader
import datetime as dt
import matplotlib.pyplot as plt
import statsmodels.api as sm
import yfinance as yf

# %%
start=dt.date(2000,1,1)
end=dt.datetime.now()
stocks=['AAPL','MSFT']

# %%
df=yf.download(stocks,start,end)
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
df
# Out:
#              Adj Close                   Close                    High  \
#                   AAPL        MSFT        AAPL        MSFT        AAPL
# Date
# 2000-01-03    0.846127   36.065559    0.999442   58.281250    1.004464
# 2000-01-04    0.774790   34.847267    0.915179   56.312500    0.987723
# 2000-01-05    0.786128   35.214684    0.928571   56.906250    0.987165
# 2000-01-06    0.718098   34.035069    0.848214   55.000000    0.955357
# 2000-01-07    0.752113   34.479862    0.888393   55.718750    0.901786
# ...                ...         ...         ...         ...         ...
# 2024-04-01  170.029999  424.570007  170.029999  424.570007  171.250000
# 2024-04-02  168.839996  421.440002  168.839996  421.440002  169.339996
# 2024-04-03  169.649994  420.450012  169.649994  420.450012  170.679993
# 2024-04-04  168.820007  417.880005  168.820007  417.880005  171.919998
# 2024-04-05  169.580002  425.519989  169.580002  425.519989  170.389999
#
#                                Low                    Open              \
#                   MSFT        AAPL        MSFT        AAPL        MSFT
# Date
# 2000-01-03   59.312500    0.907924   56.000000    0.936384   58.687500
# 2000-01-04   58.562500    0.903460   56.125000    0.966518   56.781250
# 2000-01-05   58.187500    0.919643   54.687500    0.926339   55.562500
# 2000-01-06   56.937500    0.848214   54.187500    0.947545   56.093750
# 2000-01-07   56.125000    0.852679   53.656250    0.861607   54.312500
# ...                ...         ...         ...         ...         ...
# 2024-04-01  427.890015  169.479996  422.220001  171.190002  423.950012
# 2024-04-02  422.380005  168.229996  417.839996  169.080002  420.109985
# 2024-04-03  423.260010  168.580002  419.089996  168.789993  419.730011
# 2024-04-04  428.670013  168.820007  417.570007  170.289993  424.989990
# 2024-04-05  426.510010  168.949997  418.320007  169.589996  420.010010
#
#                Volume
#                  AAPL      MSFT
# Date
# 2000-01-03  535796800  53228400
# 2000-01-04  512377600  54119000
# 2000-01-05  778321600  64059600
# 2000-01-06  767972800  54976600
# 2000-01-07  460734400  62013600
# ...               ...       ...
# 2024-04-01   46240500  16316000
# 2024-04-02   49329500  17912000
# 2024-04-03   47602100  16475600
# 2024-04-04   53704400  19370900
# 2024-04-05   42055200  16544300
#
# [6103 rows x 12 columns]

# %%
df=yf.download(stocks,start,end)['Adj Close']
# Out:
# [*********************100%%**********************]  2 of 2 completed

# %%
df
# Out:
#                   AAPL        MSFT
# Date
# 2000-01-03    0.846127   36.065567
# 2000-01-04    0.774790   34.847263
# 2000-01-05    0.786128   35.214695
# 2000-01-06    0.718097   34.035069
# 2000-01-07    0.752113   34.479839
# ...                ...         ...
# 2024-04-01  170.029999  424.570007
# 2024-04-02  168.839996  421.440002
# 2024-04-03  169.649994  420.450012
# 2024-04-04  168.820007  417.880005
# 2024-04-05  169.580002  425.519989
#
# [6103 rows x 2 columns]

# %%
daily_cum_returns=(daily_returns+1).cumprod()
daily_cum_returns
# Out:
#                   AAPL       MSFT
# Date
# 2000-01-03         NaN        NaN
# 2000-01-04    0.915690   0.966220
# 2000-01-05    0.929090   0.976407
# 2000-01-06    0.848688   0.943700
# 2000-01-07    0.888889   0.956032
# ...                ...        ...
# 2024-04-01  200.950912  11.772168
# 2024-04-02  199.544501  11.685382
# 2024-04-03  200.501801  11.657932
# 2024-04-04  199.520877  11.586673
# 2024-04-05  200.419080  11.798508
#
# [6103 rows x 2 columns]

# %%
df.plot()
plt.show()

# %%
daily_returns=df.pct_change()
daily_returns
# Out:
#                 AAPL      MSFT
# Date
# 2000-01-03       NaN       NaN
# 2000-01-04 -0.084310 -0.033780
# 2000-01-05  0.014633  0.010544
# 2000-01-06 -0.086538 -0.033498
# 2000-01-07  0.047369  0.013068
# ...              ...       ...
# 2024-04-01 -0.008456  0.009151
# 2024-04-02 -0.006999 -0.007372
# 2024-04-03  0.004797 -0.002349
# 2024-04-04 -0.004892 -0.006113
# 2024-04-05  0.004502  0.018283
#
# [6103 rows x 2 columns]

# %% [markdown]
# ## Cumulative retuns comparision

# %%
daily_cum_returns.plot()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
daily_returns.plot()
plt.show()
