# %%
import yfinance as yf
import mplfinance as mpf

# %%
pip install mplfinance
# Out:
# ...
#   Obtaining dependency information for mplfinance from https://files.pythonhosted.org/packages/d7/d9/31c436ea7673c21a5bf3fc747bc7f63377582dfe845c3004d3e46f9deee0/mplfinance-0.12.10b0-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------------------------------- 75.0/75.0 kB 1.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
df=yf.download('AAPL',start='2023-12-01')
df
# Out:
# [*********************100%%**********************]  1 of 1 completed
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2023-12-01  190.330002  191.559998  189.229996  191.240005  190.996292
# 2023-12-04  189.979996  190.050003  187.449997  189.429993  189.188583
# 2023-12-05  190.210007  194.399994  190.179993  193.419998  193.173508
# 2023-12-06  194.449997  194.759995  192.110001  192.320007  192.074921
# 2023-12-07  193.630005  195.000000  193.589996  194.270004  194.022430
# ...                ...         ...         ...         ...         ...
# 2024-04-09  168.699997  170.080002  168.350006  169.669998  169.669998
# 2024-04-10  168.800003  169.089996  167.110001  167.779999  167.779999
# 2024-04-11  168.339996  175.460007  168.160004  175.039993  175.039993
# 2024-04-12  174.259995  178.360001  174.210007  176.550003  176.550003
# 2024-04-15  175.360001  176.630005  172.500000  172.690002  172.690002
#
#                Volume
# Date
# ...

# %%
mpf.plot(df,type='candle',volume=True,mav=(5,10),tight_layout=True,style='yahoo',show_nontrading=True)

# %%
# dir(mpf)
mpf.available_styles()
# Out:
# ['binance',
#  'binancedark',
#  'blueskies',
#  'brasil',
#  'charles',
#  'checkers',
#  'classic',
#  'default',
#  'ibd',
#  'kenan',
#  'mike',
#  'nightclouds',
#  'sas',
#  'starsandstripes',
#  'tradingview',
#  'yahoo']
